# %% [markdown]
# <a href="https://www.kaggle.com/code/antoinetheissen75/mnist-model-for-begginer?scriptVersionId=155532090" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # MNIST Model
# Hello everyone !
#
# Here is one of my first "Deep Learning project"
# The MNIST Dataset is a cool dataset of hand written digits, they are placed on a 28x28 grid. It would be important for the following explenation.
#
# For this Model we will used Tensorflow and only tensorflow
#
# to install it you could use this command
# ```sh
#     pip install tensorflow
# ```

# %%
# %pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# We import tensorflow as tf because tf is easyer to write
import tensorflow as tf

# %%
#Import dataset using Tensorflow

mnist = tf.keras.datasets.mnist
#Separating the data between the 'TrainSet' and the 'TestSet'
(x_train,y_train),(x_test,y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#Using the normalize function helps to prevent loss of information during training and also ensures that the model can generalize well on unseen data.
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
#Choosing the models "Sequential()"
model = tf.keras.models.Sequential()

# %%
# Here we used the"layers Flatten" to put the image who is a 2d vector into a 1d vector from (28x28) to (1x784)
# This Layer is the entry one


model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
#Here is the building the two "hiden layers" Who will ajst the wheigt and biais of the neural network
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
#Here is the output of the neural network, There is only 10 possible output so the output number is 10.
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
#Here is the compile fonction where we define 
# Why Adam ? This is what i found in the tensorflow docs
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Fiting the model using the fit() function
model.fit(x_train, y_train, epochs=3)
#Adding epochs can help improving the accuracy
model_5 = model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2655 - accuracy: 0.9219
# Epoch 2/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1079 - accuracy: 0.9670
# Epoch 3/3
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0747 - accuracy: 0.9762
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0536 - accuracy: 0.9826
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0423 - accuracy: 0.9864
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0335 - accuracy: 0.9889
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0255 - accuracy: 0.9912
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0219 - accuracy: 0.9926

# %% [markdown]
# ## Output analysis
#
# We can check the mean of the 2 epochs :
# - The model_3 with 3 epoch have a accuracy of 95,54% and a loss of 0,1480
# - The model_5 with 5 epoch have a accuracy of 98,88% and a loss of 0,138
#
# We can see that the at the 3/3 epochs the accuracy was at 97,77% and at the 5/5 epochs the acuracy was at 99,26%
# Wich means that for 100 image tested, 0,74% were missclasified

# %%
#Saving the modele
model.save('numberRecognition.model')

# %%
#Loading the model

#new_model = tf.keras.load_model('numberRecognition.model')

# %%
# Evaluating the loss and the accuracy of the model.
loss, accuracy = model.evaluate(x_test,y_test)
print(loss)
print(accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9767
# 0.08857528865337372
# 0.9767000079154968
